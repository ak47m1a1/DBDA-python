# %%
import numpy as np
import pandas as pd
import urllib.request
import json
import requests

# %% [markdown]
# ***Sign up NYT APIs and look for dataset***

# %% [markdown]
# **First dataset**

# %%
#using NYT Article Search API to look up articles by keyword.
url ='https://api.nytimes.com/svc/search/v2/articlesearch.json?facet=false&api-key=mzhG97c91Ah7GloCw4ycQlKO8JaXQIjg'
art= requests.get(url)
print(art.text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","response":{"docs":[{"web_url":"https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE","snippet":"WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.","lead_paragraph":"WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.","print_page":"30","blog":{},"source":"The New York Times","multimedia":[],"headline":{"main":"PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians","kicker":null,"content_kicker":null,"print_headline":null,"name":null,"seo":null,"sub":null},"keywords":[{"name":"subject","value":"INDIANS, AMERI
# ...

# %%
#second, translate data to json file
art1=art.json()
art1
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE',
#     'snippet': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'lead_paragraph': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'print_page': '30',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians',
#      'kicker': None,
#      'content_kicker': None,
# ...

# %%
# check the content of the list
art2 = art1['response']['docs']
art2
# Out:
# [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE',
#   'snippet': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#   'lead_paragraph': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#   'print_page': '30',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'INDIANS, AMERICAN',
# ...

# %%
#this list shows all the article published in the New York Times
# now convert some of the extracted JSON data into a data frame
art=pd.DataFrame(art2, columns=['web_url','snippet','lead_paragraph','print_page','source'])
art
# Out:
#                                              web_url  \
# 0  https://query.nytimes.com/gst/abstract.html?re...
# 1  https://query.nytimes.com/gst/abstract.html?re...
# 2  https://query.nytimes.com/gst/abstract.html?re...
# 3  https://query.nytimes.com/gst/abstract.html?re...
# 4  https://query.nytimes.com/gst/abstract.html?re...
# 5  https://query.nytimes.com/gst/abstract.html?re...
# 6  https://query.nytimes.com/gst/abstract.html?re...
# 7  https://query.nytimes.com/gst/abstract.html?re...
# 8  https://query.nytimes.com/gst/abstract.html?re...
# 9  https://query.nytimes.com/gst/abstract.html?re...
#
#                                              snippet  \
# 0  WASHINGTON, May 16-- The Administration propos...
# 1  Charlie Wohlstetter and Phil Lucier are probab...
# 2  Darryl F. Zanuck, one of the last of the great...
# 3  WASHINGTON, June 29 The Federal Reserve Board ...
# 4  4 economists hold dollar would be strengthened...
# 5  Wiretaps in which Suffolk County Judge Floyd S...
# ...

# %% [markdown]
# **Second dataset**

# %%
#Using NYT top stories about food
url2='https://api.nytimes.com/svc/topstories/v2/food.json?api-key=mzhG97c91Ah7GloCw4ycQlKO8JaXQIjg'
food=requests.get(url2)
food
# Out:
# <Response [200]>

# %%
# now convert the 'food' object's JSON content into a list of 
# native Python objects
food1=food.json()
food1
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'section': 'food',
#  'last_updated': '2019-04-08T00:07:14-04:00',
#  'num_results': 32,
#  'results': [{'section': 'Food',
#    'subsection': '',
#    'title': 'A Sprightly Brisket for Your Passover Table',
#    'abstract': 'Braised with tangy citrus and garlic, and topped with a mix of spring lettuces and herbs, this is no stodgy Passover main.',
#    'url': 'https://www.nytimes.com/2019/04/05/dining/brisket-recipe.html',
#    'byline': 'By MELISSA CLARK',
#    'item_type': 'Article',
#    'updated_date': '2019-04-05T11:42:56-04:00',
#    'created_date': '2019-04-05T11:42:56-04:00',
#    'published_date': '2019-04-05T11:42:56-04:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Cooking and Cookbooks', 'Passover', 'Beef'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
# ...

# %%
# check the content of the list
food2=food1['results']
food2
# Out:
# [{'section': 'Food',
#   'subsection': '',
#   'title': 'A Sprightly Brisket for Your Passover Table',
#   'abstract': 'Braised with tangy citrus and garlic, and topped with a mix of spring lettuces and herbs, this is no stodgy Passover main.',
#   'url': 'https://www.nytimes.com/2019/04/05/dining/brisket-recipe.html',
#   'byline': 'By MELISSA CLARK',
#   'item_type': 'Article',
#   'updated_date': '2019-04-05T11:42:56-04:00',
#   'created_date': '2019-04-05T11:42:56-04:00',
#   'published_date': '2019-04-05T11:42:56-04:00',
#   'material_type_facet': '',
#   'kicker': '',
#   'des_facet': ['Cooking and Cookbooks', 'Passover', 'Beef'],
#   'org_facet': [],
#   'per_facet': [],
#   'geo_facet': [],
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2019/04/10/dining/05appe5/05appe5-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
# ...

# %%
# now convert some of the extracted JSON data into a data frame
food3=pd.DataFrame(food2,columns=['section','title','abstract','url','byline','item_type','updated_date','created_date',
                                 'published_date','material_type_facet','kicker'])
food3
# Out:
#         section                                              title  \
# 0          Food        A Sprightly Brisket for Your Passover Table
# 1          Food                                This Is Peak Potato
# 2          Food  Simply Cooked Seafood Turns Luxurious at Taver...
# 3          Food  The Big Reverb of Australia’s Lo-Fi Wine Movement
# 4          Food  Shaken? Stirred? Sorry, Your Martini Has Alrea...
# 5          Food  Does the Air Fryer Deliver on Its Golden Promise?
# 6          Food  Undercover and Overworked: Inside the New, Ner...
# 7          Food  The TV Chef Rocco DiSpirito Returns, With a Qu...
# 8          Food  Stylish Cafeteria From Dean & DeLuca Opens in ...
# 9          Food                 Zagat Guide Will Reappear in Print
# 10         Food         A New Role for Madhur Jaffrey: Rap Grandma
# 11     Magazine   These Date-and-Walnut Bars Are Food for the Gods
# 12         Food  Mercurey: Exploring Burgundy’s Periphery for A...
# ...
